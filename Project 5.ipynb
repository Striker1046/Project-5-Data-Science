# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import necessary packages

# Read in data file
democracy_df = pd.read_csv("distribution-electoral-democracy-vdem.csv")
democracy_df.describe()
# Out:
#                Year  electdem_vdem_owid
# count  33808.000000        32518.000000
# mean    1921.300077            0.234896
# std       65.503517            0.249806
# min     1789.000000            0.006000
# 25%     1867.000000            0.042000
# 50%     1930.000000            0.142000
# 75%     1977.000000            0.317000
# max     2022.000000            0.924000

# %%
democracy_df.head()
# Out:
#         Entity Code  Year  electdem_vdem_owid region
# 0  Afghanistan  AFG  1789               0.019   Asia
# 1  Afghanistan  AFG  1790               0.019   Asia
# 2  Afghanistan  AFG  1791               0.019   Asia
# 3  Afghanistan  AFG  1792               0.019   Asia
# 4  Afghanistan  AFG  1793               0.019   Asia

# %%
democracy_2022_df = democracy_df[democracy_df["Year"] == 2022]
democracy_2022_df.head()
# Out:
#           Entity Code  Year  electdem_vdem_owid  region
# 233  Afghanistan  AFG  2022            0.082000    Asia
# 467       Africa  NaN  2022            0.389125   World
# 576      Albania  ALB  2022            0.484000  Europe
# 701      Algeria  DZA  2022            0.281000  Africa
# 824       Angola  AGO  2022            0.344000  Africa

# %%
democracy_2022_df = democracy_2022_df.sort_values (by = "electdem_vdem_owid", ascending = False)
democracy_2022_df
# Out:
#              Entity Code  Year  electdem_vdem_owid  region
# 7623        Denmark  DNK  2022               0.916  Europe
# 28905        Sweden  SWE  2022               0.899  Europe
# 22021        Norway  NOR  2022               0.899  Europe
# 29130   Switzerland  CHE  2022               0.898  Europe
# 9093        Estonia  EST  2022               0.893  Europe
# ...             ...  ...   ...                 ...     ...
# 21571   North Korea  PRK  2022               0.087    Asia
# 233     Afghanistan  AFG  2022               0.082    Asia
# 5840          China  CHN  2022               0.075    Asia
# 8859        Eritrea  ERI  2022               0.073  Africa
# 25545  Saudi Arabia  SAU  2022               0.016    Asia
#
# [186 rows x 5 columns]

# %%
democracy_2022_df.plot.bar("Entity", "electdem_vdem_owid")
# Out:
# <AxesSubplot:xlabel='Entity'>

# %%
plt.bar(democracy_2022_df["Entity"], democracy_2022_df["electdem_vdem_owid"], width = 0.4)
# Out:
# <BarContainer object of 186 artists>
